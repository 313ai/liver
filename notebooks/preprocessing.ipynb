# %%
# %pylab inline
import pandas as pd
import numpy as np
import openslide
import glob
import tqdm
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dpath = "/DATA/GDC/lana/"

# %%
slides = glob.glob(dpath + "*/*.svs")

# %%
def get_thumb(fn, thumb_size=(200,200)):
    slide = openslide.open_slide(fn)
    thumb = slide.get_thumbnail(thumb_size)
    slide.close()
    return thumb

# %%
thumb = get_thumb(random.choice(slides))

# %%
thumb
# Out:
# <PIL.Image.Image image mode=RGB size=200x70 at 0x7F266E923898>

# %%
thumb_size = (50,25)
num_slides = 50
slide_sample = random.choice(slides, size=num_slides, replace=False)
plt.figure(figsize=thumb_size)
columns = 5
for i, slide_fn in tqdm.tqdm_notebook(enumerate(slide_sample), total=num_slides):
    plt.subplot(len(slide_sample) / columns + 1, columns, i + 1)
    plt.imshow(get_thumb(slide_fn, thumb_size=thumb_size))

# %%
slide = openslide.open_slide?

# %%
slide = openslide.open_slide(random.choice(slides))

# %%
dims = [openslide.open_slide(fn).dimensions for fn in tqdm.tqdm_notebook(slides)]

# %%
pd.DataFrame(dims).describe()
# Out:
#                    0             1
# count     492.000000    492.000000
# mean    78797.729675  27042.380081
# std     27795.302322   8691.675833
# min     11952.000000   8772.000000
# 25%     59023.000000  20654.750000
# 50%     84021.500000  27009.000000
# 75%     98055.250000  33342.250000
# max    165648.000000  60561.000000
